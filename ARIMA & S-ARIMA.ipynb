# %% [markdown]
# # S&P 500 Diskrete Mathematik und Stochastik

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Immer helle Diagramme
plt.style.use('default')

# %% [markdown]
# ### 1. Daten laden (Index)
# Der Datensatz stammt von https://www.kaggle.com/datasets/andrewmvd/sp-500-stocks/versions/1022
#
# Dabei werden  die Dateien  sp500_companies.csv, sp500_index.csv und sp500_stocks.csv geliefert. Die neuste Version enthält dabei nicht alle Daten und wird hier nicht verwendet.

# %%
# Daten laden --> Es werden nur die Indexdaten betrachtet
df = pd.read_csv('data2/sp500_index.csv')

# %%
# Erster Dateneinblick
print(df.head())
print(df.info())
print(df.describe())
# Out:
#          Date   S&P500
# 0  2014-12-22  2078.54
# 1  2014-12-23  2082.17
# 2  2014-12-24  2081.88
# 3  2014-12-26  2088.77
# 4  2014-12-29  2090.57
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2517 non-null   object
#  1   S&P500  2517 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 39.5+ KB
# None
#             S&P500
# count  2517.000000
# mean   3346.351605
# std    1078.204274
# min    1829.080000
# 25%    2428.370000
# 50%    2999.910000
# 75%    4199.120000
# max    6090.270000

# %% [markdown]
# ### 2. Index erstellen
# Aktienkurse sind Zeitreihen. Das Datum muss als technischer Index dienen, um Berechnungen (wie Renditen) korrekt durchzuführen.

# %%
# Konvertierung in Datetime
df['Date'] = pd.to_datetime(df['Date'])

# Zeitstempel als Index setzen
df.set_index('Date', inplace=True)

# Daten sortieren
df.sort_index(inplace=True)

# %% [markdown]
# ### 3. Auf Duplikate prüfen
# Die Deduplizierung stellt sicher, dass jeder Tag nur einmal vorkommt, um Widersprüche in der Analyse zu vermeiden.

# %%
# Identifikation von Duplikaten im Index
duplicates = df.index.duplicated().sum()
print(f"Anzahl Duplikate: {duplicates}")

# Bereinigung
df = df[~df.index.duplicated(keep='first')]
# Out:
# Anzahl Duplikate: 0

# %% [markdown]
# ### 4. Auf Datenlücken prüfen

# %%
# Fehlende Werte prüfen
print(df.isnull().sum())

# Wochenenden und Feiertage kurs weitertragen
# Konsistenzprüfung: Resampling auf Geschäftstage ('B')
# ffill (forward fill) überträgt den letzten bekannten Kurs auf den nächsten Tag
df_cleaned = df['S&P500'].resample('B').ffill()
df_cleaned = df_cleaned.to_frame(name='SP500')

# Plausibilitätscheck: Gibt es unrealistische Sprünge?
print(df_cleaned.describe())
print(df_cleaned.head())
# Out:
# S&P500    0
# dtype: int64
#              SP500
# count  2610.000000
# mean   3345.529552
# std    1077.892473
# min    1829.080000
# 25%    2426.020000
# 50%    2998.935000
# 75%    4198.852500
# max    6090.270000
#               SP500
# Date
# 2014-12-22  2078.54
# 2014-12-23  2082.17
# 2014-12-24  2081.88
# 2014-12-25  2081.88
# 2014-12-26  2088.77

# %% [markdown]
# ### 5. Bereinigten Kurs anzeigen lassen
#  Ein S&P 500 Chart zeigt meist einen langfristigen Aufwärtstrend --> ein klares Zeichen für Nicht-Stationarität.

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_cleaned.index, df_cleaned['SP500'], label='S&P 500 Schlusskurs')
plt.title('S&P 500 Zeitreihe (df_cleaned)')
plt.xlabel('Datum')
plt.ylabel('Preis in Punkten')
plt.legend()
plt.show()

# %% [markdown]
# ### 6. Stationarität prüfen (Augmented Dickey-Fuller (ADF) Test)
# ADF-Test --> statistisch zu prüfen, ob die Zeitreihe stationär ist
#
# Nullhypothese ($H_0$): Die Zeitreihe ist nicht-stationär (besitzt eine Einheitswurzel).
#
# Alternativhypothese ($H_1$): Die Zeitreihe ist stationär.

# %%
def print_adf_results(series):
    result = adfuller(series)
    print(f'ADF Statistic: {result[0]:.4f}')
    print(f'p-value: {result[1]:.4f}')
    if result[1] <= 0.05:
        print("=> Die Zeitreihe ist stationär (H0 abgelehnt).")
    else:
        print("=> Die Zeitreihe ist NICHT stationär (H0 kann nicht abgelehnt werden).")

print_adf_results(df_cleaned['SP500'])
# Out:
# ADF Statistic: 0.7068
# p-value: 0.9900
# => Die Zeitreihe ist NICHT stationär (H0 kann nicht abgelehnt werden).

# %% [markdown]
# ### 7. Stationarität durch Differenzierung herstellen
# Aktienpreise --> meist nicht stationär sind --> müssen differenzieren ($d$). Ergebnis: Wenn der p-Wert nun $\le 0,05$ ist, haben wir unser $d=1$ gefunden.

# %%
# Erste Differenzierung (d=1)
df_diff = df_cleaned['SP500'].diff().dropna()

# Erneuter Test der differenzierten Daten
print("Ergebnisse nach der 1. Differenzierung:")
print_adf_results(df_diff)
# Out:
# Ergebnisse nach der 1. Differenzierung:
# ADF Statistic: -13.6686
# p-value: 0.0000
# => Die Zeitreihe ist stationär (H0 abgelehnt).

# %% [markdown]
# ### 8. p und q bestimmen (ACF und PACF Plots)
# Parameter für den autoregressiven Teil ($p$) und den gleitenden Durchschnitt ($q$) -->  Korrelationsplots:
# ACF (Autocorrelation Function): Hilft bei der Bestimmung von $q$.
# PACF (Partial Autocorrelation Function): Hilft bei der Bestimmung von $p$.
#
# PACF: Wenn der Plot nach dem ersten Lag (Balken) drastisch abfällt, deutet das auf ein $p=1$ hin.
# ACF: Wenn die Korrelation nach dem ersten Lag gegen Null geht, deutet das auf ein $q=1$ hin.

# %%
# numerische ACF- und PACF-Werte berechnen
acf_vals = acf(df_diff, nlags=40)
pacf_vals = pacf(df_diff, nlags=40, method='ywm')

print("ACF-Werte (Lag 0..40):")
print(acf_vals)

print("\nPACF-Werte (Lag 0..40):")
print(pacf_vals)
# Out:
# ACF-Werte (Lag 0..40):
# [ 1.00000000e+00 -7.69248874e-02  3.87129108e-02 -2.18620167e-02
#  -1.57824668e-02  9.11820243e-03 -7.55581397e-02  7.75076009e-02
#  -7.10627037e-02  1.34966784e-01 -8.15477666e-02  1.58822046e-02
#   1.09090811e-02 -6.19910436e-02  4.08796953e-02 -5.14796166e-02
#  -2.04382352e-03 -7.40713600e-03  1.79409319e-02 -4.98900356e-03
#  -1.21357856e-02  2.09827026e-02 -4.08451495e-03 -1.87065231e-02
#  -2.25677339e-02  2.69958520e-02 -2.96945994e-02 -4.77682926e-02
#   4.67021356e-02 -1.01866864e-03 -2.43719596e-02 -1.97572559e-03
#  -1.87047903e-02 -9.43447009e-03  3.36396583e-03  1.58462910e-03
#  -9.54336637e-04  1.61864606e-02 -1.60090994e-02  1.60465198e-02
#  -1.23457911e-02]
#
# PACF-Werte (Lag 0..40):
# [ 1.         -0.07692489  0.03299069 -0.01656038 -0.02004592  0.00787256
#  -0.07398273  0.06607857 -0.05671627  0.12126932 -0.06355594  0.0019359
#   0.01164567 -0.0503575   0.01912783 -0.0205421  -0.03948801  0.01696767
#  -0.00472553  0.00447523 -0.00857319  0.00462747  0.01868789 -0.0362615
#  -0.0144284   0.02870262 -0.03700139 -0.04856634  0.04017868  0.00341049
#  -0.03127714 -0.0040157  -0.01879736 -0.01256716  0.00371496  0.00384809
#   0.00274881  0.00283063 -0.01124637  0.01577959 -0.01830375]

# %%
acf_vals, acf_conf = acf(df_diff, nlags=40, alpha=0.05)
pacf_vals, pacf_conf = pacf(df_diff, nlags=40, alpha=0.05, method='ywm')

print("ACF Konfidenzintervalle:")
print(acf_conf)

print("\nPACF Konfidenzintervalle:")
print(pacf_conf)
# Out:
# ACF Konfidenzintervalle:
# [[ 1.00000000e+00  1.00000000e+00]
#  [-1.15296588e-01 -3.85531865e-02]
#  [ 1.14815474e-04  7.73110060e-02]
#  [-6.05172397e-02  1.67932062e-02]
#  [-5.44558906e-02  2.28909571e-02]
#  [-2.95647035e-02  4.78011084e-02]
#  [-1.14244210e-01 -3.68720693e-02]
#  [ 3.86048521e-02  1.16410350e-01]
#  [-1.10192160e-01 -3.19332469e-02]
#  [ 9.56477649e-02  1.74285802e-01]
#  [-1.21543108e-01 -4.15524251e-02]
#  [-2.43572066e-02  5.61216157e-02]
#  [-2.93395588e-02  5.11577210e-02]
#  [-1.02244037e-01 -2.17380504e-02]
#  [ 4.86380150e-04  8.12730104e-02]
#  [-9.19338014e-02 -1.10254318e-02]
#  [-4.25943496e-02  3.85067026e-02]
#  [-4.79578138e-02  3.31435418e-02]
#  [-2.26117379e-02  5.84936018e-02]
#  [-4.55533585e-02  3.55753513e-02]
#  [-5.27010440e-02  2.84294727e-02]
#  [-1.95879011e-02  6.15533062e-02]
#  [-4.46710939e-02  3.65020640e-02]
#  [-5.92937073e-02  2.18806610e-02]
#  [-6.31676107e-02  1.80321429e-02]
#  [-1.36224909e-02  6.76141948e-02]
#  [-7.03393514e-02  1.09501525e-02]
#  [-8.84449747e-02 -7.09161043e-03]
#  [ 5.94294169e-03  8.74613295e-02]
#  [-4.18565763e-02  3.98192390e-02]
#  [-6.52099047e-02  1.64659855e-02]
#  [-4.28350811e-02  3.88836299e-02]
#  [-5.95642865e-02  2.21547059e-02]
#  [-5.03065720e-02  3.14376318e-02]
#  [-3.75113425e-02  4.42392741e-02]
#  [-3.92910868e-02  4.24603450e-02]
#  [-4.18301430e-02  3.99214697e-02]
#  [-2.46893785e-02  5.70622998e-02]
#  [-5.68943750e-02  2.48761762e-02]
#  [-2.48479845e-02  5.69410241e-02]
#  [-5.32495652e-02  2.85579830e-02]]
#
# PACF Konfidenzintervalle:
# [[ 1.          1.        ]
#  [-0.11529659 -0.03855319]
#  [-0.00538101  0.07136239]
#  [-0.05493208  0.02181132]
#  [-0.05841763  0.01832578]
#  [-0.03049914  0.04624427]
#  [-0.11235443 -0.03561103]
#  [ 0.02770687  0.10445027]
#  [-0.09508797 -0.01834457]
#  [ 0.08289762  0.15964102]
#  [-0.10192764 -0.02518424]
#  [-0.0364358   0.0403076 ]
#  [-0.02672603  0.05001737]
#  [-0.0887292  -0.0119858 ]
#  [-0.01924387  0.05749953]
#  [-0.0589138   0.0178296 ]
#  [-0.07785971 -0.00111631]
#  [-0.02140403  0.05533937]
#  [-0.04309723  0.03364617]
#  [-0.03389647  0.04284693]
#  [-0.04694489  0.02979851]
#  [-0.03374423  0.04299917]
#  [-0.01968381  0.05705959]
#  [-0.0746332   0.0021102 ]
#  [-0.0528001   0.0239433 ]
#  [-0.00966909  0.06707432]
#  [-0.07537309  0.00137031]
#  [-0.08693804 -0.01019464]
#  [ 0.00180698  0.07855038]
#  [-0.03496121  0.04178219]
#  [-0.06964884  0.00709456]
#  [-0.0423874   0.034356  ]
#  [-0.05716906  0.01957435]
#  [-0.05093886  0.02580454]
#  [-0.03465674  0.04208666]
#  [-0.03452362  0.04221979]
#  [-0.03562289  0.04112051]
#  [-0.03554107  0.04120233]
#  [-0.04961807  0.02712533]
#  [-0.02259211  0.05415129]
#  [-0.05667545  0.02006795]]

# %% [markdown]
# keine starken, systematischen Autokorrelationen mehr, also ungefähr „weißes Rauschen“
#
# ### ACF-Werte
# Lag 1: etwa −0,077
# −0,077 → leicht negative Autokorrelation in der ersten Differenz, aber relativ klein.
#
# Die restlichen Lags liegen überwiegend zwischen etwa −0,08 und +0,13, ohne klares Muster (kein langsames Abklingen, kein konstantes Vorzeichen usw.).
#
# Das deutet eher auf keinen stark ausgeprägten MA-Anteil hin (kein Abschneiden der ACF nach einem kleinen Lag q). []
#
# ### Interpretation:
# Die differenzierte Reihe scheint näherungsweise stationär zu sein. Es gibt keine klar dominierende Struktur in der ACF, also keinen offensichtlichen reinen MA(q)-Prozess kleiner Ordnung.
#
# ### PACF-Werte
# Lag 1: etwa −0,077 → kleiner negativer AR‑Effekt erster Ordnung, aber wieder relativ schwach.
# Danach sind die PACF-Werte alle in einem ähnlichen kleinen Bereich und schneiden nicht „hart“ nach einem bestimmten p ab (also kein Muster „groß bei Lag 1..p, danach ~0“). []
#
# ### Interpretation:
# Es gibt keinen klaren Hinweis auf einen „reinen“ AR(p)-Prozess niedriger Ordnung.
# Dass sowohl ACF als auch PACF relativ schnell um 0 herum „ausrauschen“, passt eher zu einem ARMA‑ähnlichen oder nahezu weißen Rauschen nach der Differenzierung.

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# ACF Plot für q
plot_acf(df_diff, ax=axes[0], lags=40)
axes[0].set_title('Autokorrelation (ACF) - Bestimmung von q')

# PACF Plot für p
plot_pacf(df_diff, ax=axes[1], lags=40)
axes[1].set_title('Partielle Autokorrelation (PACF) - Bestimmung von p')

plt.show()

# %% [markdown]
# ### 9. ARIMA Modell bauen

# %%
# Modell definieren
arima_model = ARIMA(df_cleaned['SP500'], order=(1, 1, 1))
arima_result = arima_model.fit()

# Zusammenfassung anzeigen
print(arima_result.summary())

# Vorhersage für die nächsten 5 Tage
forecast_arima = arima_result.get_forecast(steps=5)
print(forecast_arima.summary_frame())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  SP500   No. Observations:                 2610
# Model:                 ARIMA(1, 1, 1)   Log Likelihood              -13087.494
# Date:                Sun, 18 Jan 2026   AIC                          26180.987
# Time:                        11:15:10   BIC                          26198.587
# Sample:                    12-22-2014   HQIC                         26187.363
#                          - 12-20-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3972      0.098     -4.066      0.000      -0.589      -0.206
# ma.L1          0.3215      0.102      3.167      0.002       0.123       0.521
# sigma2      1333.6005     17.974     74.197      0.000    1298.373    1368.828
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              6053.43
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               6.67   Skew:                            -0.68
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.34
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# SP500              mean    mean_se  mean_ci_lower  mean_ci_upper
# 2024-12-23  5927.222757  36.518495    5855.647823    5998.797691
# 2024-12-24  5928.663549  49.729049    5831.196404    6026.130694
# 2024-12-25  5928.091246  60.726231    5809.070020    6047.112472
# 2024-12-26  5928.318573  69.800900    5791.511322    6065.125824
# 2024-12-27  5928.228275  77.901278    5775.544577    6080.911974

# %% [markdown]
# ### 10. S ARIMA bauen
# S-ARIMA berücksichtigt zusätzlich saisonale Muster. Aktienmärkte = oft wöchentliche Zyklen -->  Saisonalität von $s=5$ (5 Handelstage pro Woche).

# %%
# S-ARIMA mit wöchentlicher Saisonalität (s=5)
sarima_model = SARIMAX(df_cleaned['SP500'],
                       order=(1, 1, 1),
                       seasonal_order=(1, 1, 1, 5))
sarima_result = sarima_model.fit()

print(sarima_result.summary())

# Vorhersage für die nächsten 5 Tage
forecast_sarima = sarima_result.get_forecast(steps=5)
print(forecast_sarima.summary_frame())
# Out:
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                             SP500   No. Observations:                 2610
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 5)   Log Likelihood              -13078.011
# Date:                           Sun, 18 Jan 2026   AIC                          26166.023
# Time:                                   11:15:11   BIC                          26195.347
# Sample:                               12-22-2014   HQIC                         26176.647
#                                     - 12-20-2024
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3914      0.099     -3.943      0.000      -0.586      -0.197
# ma.L1          0.3148      0.104      3.040      0.002       0.112       0.518
# ar.S.L5        0.0032      0.012      0.274      0.784      -0.020       0.026
# ma.S.L5       -0.9994      0.026    -38.584      0.000      -1.050      -0.949
# sigma2      1333.0127     39.181     34.022      0.000    1256.220    1409.805
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              5924.41
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               6.62   Skew:                            -0.68
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# SP500              mean    mean_se  mean_ci_lower  mean_ci_upper
# 2024-12-23  5928.845165  36.535853    5857.236210    6000.454120
# 2024-12-24  5931.507783  49.728438    5834.041835    6028.973731
# 2024-12-25  5931.984385  60.713567    5812.987980    6050.980790
# 2024-12-26  5933.005433  69.782853    5796.233553    6069.777312
# 2024-12-27  5935.299565  77.876450    5782.664528    6087.934602

# %% [markdown]
# ### 12. Vergleich

# %%
#ARIMA
# Beispiel: Wir vergleichen die letzten 5 Tage (Test-Daten)
test_data = df_cleaned['SP500'][-5:]
predictions_arima = forecast_arima.predicted_mean

rmse_arima = np.sqrt(mean_squared_error(test_data, predictions_arima))
print(f"ARIMA RMSE: {rmse_arima:.2f}")

# (Wiederhole dies für S-ARIMA zum Vergleich)
#S ARIMA
test_data = df_cleaned['SP500'][-5:]
predictions_sarima = forecast_sarima.predicted_mean

rmse_arima = np.sqrt(mean_squared_error(test_data, predictions_sarima))
print(f"ARIMA RMSE: {rmse_arima:.2f}")
# Out:
# ARIMA RMSE: 93.08
# ARIMA RMSE: 92.98

# %%
# Plot der Residuen
arima_result.plot_diagnostics(figsize=(10, 8))
plt.show()

# %% [markdown]
# ## Testvergleich

# %%
def plot_arima_sarima_comparison(df_cleaned, arima_res, sarima_res, forecast_steps=10):

    # 1. Daten für die Prognose extrahieren
    arima_forecast = arima_res.get_forecast(steps=forecast_steps)
    arima_mean = arima_forecast.predicted_mean
    arima_ci = arima_forecast.conf_int()

    sarima_forecast = sarima_res.get_forecast(steps=forecast_steps)
    sarima_mean = sarima_forecast.predicted_mean
    sarima_ci = sarima_forecast.conf_int()

    # 2. Plot-Konfiguration
    plt.figure(figsize=(14, 8))

    # Zeitraum festlegen: 30 Tage Kontext + Prognosezeitraum
    forecast_start_date = arima_mean.index[0]
    forecast_end_date = arima_mean.index[-1]
    context_start = forecast_start_date - pd.Timedelta(days=30)

    # Echte Daten für den gesamten sichtbaren Bereich (Historie + Test-Set)
    actual_full_period = df_cleaned['SP500'].loc[context_start:forecast_end_date]

    # 3. Echte Daten plotten
    #splitten die Anzeige optisch: Kontext (durchgehend) und Test-Set (mit Markern)
    plt.plot(actual_full_period, label='Echte Daten (S&P 500)', color='black', linewidth=2.5, zorder=1)

    # 4. ARIMA Vorhersage (Blau)
    plt.plot(arima_mean, label='ARIMA Prognose', color='blue', linestyle='--', linewidth=2, zorder=3)
    plt.fill_between(arima_ci.index, arima_ci.iloc[:, 0], arima_ci.iloc[:, 1], color='blue', alpha=0.1)

    # 5. SARIMA Vorhersage (Rot)
    plt.plot(sarima_mean, label='S-ARIMA Prognose', color='red', linestyle='--', linewidth=2, zorder=4)
    plt.fill_between(sarima_ci.index, sarima_ci.iloc[:, 0], sarima_ci.iloc[:, 1], color='red', alpha=0.1)

    # Styling
    plt.title(f'S&P 500 Prognose - ARIMA & S-ARIMA', fontsize=22, fontweight='bold', pad=20)
    plt.xlabel('Datum', fontsize=16)
    plt.ylabel('Indexpunkte', fontsize=16)
    plt.legend(fontsize=12, loc='upper left', frameon=True, shadow=True)
    plt.grid(True, alpha=0.3)

    # Prognosestart-Linie
    plt.axvline(x=forecast_start_date, color='gray', linestyle=':', alpha=0.7)
    plt.text(forecast_start_date, plt.ylim()[1], ' Prognosestart', fontsize=10, verticalalignment='top')

    plt.xticks(rotation=15)
    plt.tight_layout()

    # Speichern für das Poster
    plt.savefig('poster_prognose_vergleich_final.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
# 1. Daten splitten: Training bis Ende September, Test/Prognose ab 01.10.2024
train = df_cleaned['SP500'][:'2024-09-30']
test = df_cleaned['SP500']['2024-10-01':]
#train = df_cleaned['SP500'][:'2023-03-31']
#test = df_cleaned['SP500']['2023-04-01':]
# Wir nehmen z.B. 20 Schritte, um den Vergleich im Oktober gut zu sehen
steps = 20

# 2. Modelle fitten
arima_mod = ARIMA(train, order=(1,1,1))
arima_res = arima_mod.fit()

sarima_mod = SARIMAX(train, order=(1,1,1), seasonal_order=(1,1,1,5))
sarima_res = sarima_mod.fit(disp=False)

# 3. Plot aufrufen
plot_arima_sarima_comparison(df_cleaned, arima_res, sarima_res, forecast_steps=steps)

# %%
# 1. Vorhersagen extrahieren
arima_pred = arima_res.get_forecast(steps=steps).predicted_mean
sarima_pred = sarima_res.get_forecast(steps=steps).predicted_mean

# 2. Echte Werte für den Vergleichszeitraum (Oktober 2024)
actual_values = test[:steps]

# 3. Fehler-Funktion
def print_metrics(actual, predicted, label):
    mae = mean_absolute_error(actual, predicted)
    rmse = np.sqrt(mean_squared_error(actual, predicted))
    mape = np.mean(np.abs((actual - predicted) / actual)) * 100
    print(f"Metriken für {label}: MAE={mae:.2f}, RMSE={rmse:.2f}, MAPE={mape:.2f}%")

# 4. Ergebnisse ausgeben
print_metrics(actual_values, arima_pred, "ARIMA(1,1,1)")
print_metrics(actual_values, sarima_pred, "S-ARIMA(1,1,1,5)")

print(f"Modell-Vergleich (Güte der Anpassung):")
print(f"ARIMA(1,1,1):   AIC={arima_res.aic:.2f}, BIC={arima_res.bic:.2f}")
print(f"S-ARIMA(1,1,1,5): AIC={sarima_res.aic:.2f}, BIC={sarima_res.bic:.2f}")
print("-" * 30)
# Out:
# Metriken für ARIMA(1,1,1): MAE=57.60, RMSE=63.73, MAPE=0.99%
# Metriken für S-ARIMA(1,1,1,5): MAE=44.86, RMSE=51.16, MAPE=0.77%
# Modell-Vergleich (Güte der Anpassung):
# ARIMA(1,1,1):   AIC=25553.42, BIC=25570.95
# S-ARIMA(1,1,1,5): AIC=25538.63, BIC=25567.84
# ------------------------------
